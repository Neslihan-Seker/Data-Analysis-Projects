# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(
    'C:/Users/Neslihan Seker/Desktop/Data-Analysis-Projects/Handling Missing Values/Building_Permits.csv',
    low_memory=False
)

# %%
data.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
missing_values = data.isnull().sum()
missing_values[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
total_cells = np.product(data.shape)
total_missing = missing_values.sum()

(total_missing/total_cells)*100
# Out:
# 26.26002315058403

# %%
missing_values[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
data.sample(5)
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 107085       M640547            8  otc alterations permit
# 79987        M572167            8  otc alterations permit
# 93473   201507282623            8  otc alterations permit
# 125816  201605318738            8  otc alterations permit
# 45485   201404213693            8  otc alterations permit
#
#        Permit Creation Date  Block  Lot  Street Number Street Number Suffix  \
# 107085           11/24/2015   1413  005            229                  NaN
# 79987            03/24/2015   1176  011           1640                  NaN
# 93473            07/28/2015   6685  007            242                  NaN
# 125816           05/31/2016   3581  087            498                  NaN
# 45485            04/21/2014  0436D  043           3732                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 107085        20th            Av  ...                         NaN
# ...

# %%
data['Zipcode'].isnull().sum()
# Out:
# 1716

# %%
drop_columns = data.dropna(axis=1)
drop_columns.head(5)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
print('Columns in original dataset: %d \n' %data.shape [1] )
print('Columns are dropped: %d \n' %drop_columns.shape [1] )
# Out:
# Columns in original dataset: 43
#
# Columns are dropped: 12

# %%
subset_data = data.loc[:, 'Permit Type':'Street Suffix'].head()
subset_data
# Out:
#    Permit Type            Permit Type Definition Permit Creation Date Block  \
# 0            4                      sign - erect           05/06/2015  0326
# 1            4                      sign - erect           04/19/2016  0306
# 2            3  additions alterations or repairs           05/27/2016  0595
# 3            8            otc alterations permit           11/07/2016  0156
# 4            6                       demolitions           11/28/2016  0342
#
#    Lot  Street Number Street Number Suffix Street Name Street Suffix
# 0  023            140                  NaN       Ellis            St
# 1  007            440                  NaN       Geary            St
# 2  203           1647                  NaN     Pacific            Av
# 3  011           1230                  NaN     Pacific            Av
# 4  001            950                  NaN      Market            St

# %%
subset_data.isnull().sum()
# Out:
# Permit Type               0
# Permit Type Definition    0
# Permit Creation Date      0
# Block                     0
# Lot                       0
# Street Number             0
# Street Number Suffix      5
# Street Name               0
# Street Suffix             0
# dtype: int64

# %%
subset_data.fillna(0)
# Out:
# C:\Users\Neslihan Seker\AppData\Local\Temp\ipykernel_9460\1473254981.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subset_data.fillna(0)
#    Permit Type            Permit Type Definition Permit Creation Date Block  \
# 0            4                      sign - erect           05/06/2015  0326
# 1            4                      sign - erect           04/19/2016  0306
# 2            3  additions alterations or repairs           05/27/2016  0595
# 3            8            otc alterations permit           11/07/2016  0156
# 4            6                       demolitions           11/28/2016  0342
#
#    Lot  Street Number  Street Number Suffix Street Name Street Suffix
# 0  023            140                     0       Ellis            St
# ...

# %%
subset_data.fillna(method='bfill', axis=0).fillna(0)
# Out:
# C:\Users\Neslihan Seker\AppData\Local\Temp\ipykernel_9460\1950032661.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_data.fillna(method='bfill', axis=0).fillna(0)
# C:\Users\Neslihan Seker\AppData\Local\Temp\ipykernel_9460\1950032661.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subset_data.fillna(method='bfill', axis=0).fillna(0)
#    Permit Type            Permit Type Definition Permit Creation Date Block  \
# 0            4                      sign - erect           05/06/2015  0326
# 1            4                      sign - erect           04/19/2016  0306
# 2            3  additions alterations or repairs           05/27/2016  0595
# ...
